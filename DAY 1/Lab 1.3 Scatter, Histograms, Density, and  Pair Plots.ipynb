# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Edunet Foundation : Class Room Exercises

# %% [markdown]
# # Lab 1.3:   Scatter, Histograms, Density, and  Pair Plots
#
# ### Objective:
#
# The objective of the "Scatter, Histograms, Density, and Pair Plots" lab is to provide learners with practical skills in visualizing data distributions and relationships using various types of plots. The lab begins with an introduction to data visualization concepts and the importance of graphical representation in data analysis. Learners will gain hands-on experience in creating scatter plots to observe relationships between variables, histograms to visualize frequency distributions, density plots to estimate the probability density function of a continuous variable, and pair plots to explore pairwise relationships between multiple variables. By the end of the lab, learners will be proficient in using these visualization techniques to gain insights into data patterns and correlations, enhancing their ability to communicate data findings effectively.

# %%
import matplotlib.pyplot as plt


# Sample data

x_data = [1, 2, 3, 4, 5]

y_data = [2, 3, 5, 7, 11]

# Create scatter plot

plt.figure(figsize=(8, 6))  # Optional: Adjust figure size

plt.scatter(x_data, y_data, color='blue', marker='o', label='Data points')

# Customize labels and title

plt.xlabel('X-axis label')

plt.ylabel('Y-axis label')

plt.title('Scatter Plot Example')

plt.legend()  # Show legend based on 'label' in scatter plot

# Show plot

plt.grid(True)  # Optional: Add grid

plt.tight_layout()  # Optional: Adjust layout

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (randomly generated)
data = np.random.randn(1000)  # Generate 1000 random values from a normal distribution

# Create histogram
plt.figure(figsize=(8, 6))
plt.hist(data, bins=30, density=False, alpha=0.75, color='blue')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Data')
plt.grid(True)
plt.show()

# %% [markdown]
# Explanation:
#
# 1. plt.hist(data, bins=30, density=False, alpha=0.75, color='blue')
#
#    creates a histogram:
#
#    1.1 data: The array of values to be plotted.
#
#    1.2 bins=30: Number of bins (intervals) to divide the data range into.
#
#    1.3 density=False: If True, the histogram will show a probability density rather than counts.
#
#    1.4 alpha=0.75: Transparency of bars (0 for transparent, 1 for opaque).
#
#    1.5 color='blue': Color of bars in the histogram.
# 3. plt.xlabel(), plt.ylabel(), plt.title(): Add labels and a title to the plot.
#
# 4. plt.grid(True): Optionally add grid lines to the plot for better readability.

# %% [markdown]
# ## Density Plots Using Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example data (using the Iris dataset for illustration)
data = sns.load_dataset("iris")

# Create density plot
plt.figure(figsize=(8, 6))
sns.kdeplot(data['sepal_length'], shade=True, color='g', label='Sepal Length')
sns.kdeplot(data['sepal_width'], shade=True, color='b', label='Sepal Width')
plt.xlabel('Values')
plt.ylabel('Density')
plt.title('Density Plot of Sepal Measurements')
plt.legend()
plt.show()
# Out:
# C:\Users\RAMAR BOSE\AppData\Local\Temp\ipykernel_6836\3278256550.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['sepal_length'], shade=True, color='g', label='Sepal Length')
# C:\Users\RAMAR BOSE\AppData\Local\Temp\ipykernel_6836\3278256550.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['sepal_width'], shade=True, color='b', label='Sepal Width')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt



# Example data (you can load your own dataset here)

df = sns.load_dataset('iris')  # Example dataset from Seaborn



# Create pair plot

sns.pairplot(df, kind='scatter', diag_kind='hist')


# Show plot

plt.show()
# Out:
# C:\Users\AbdulAziz\anaconda3\envs\env_face\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
